# %%
import pandas as pd
df = pd.read_csv('/code/data/train.csv')

fake = df.loc[df['is_sarcastic'] == 1]
real = df.loc[df['is_sarcastic'] == 0]

# %%
fake_len = fake['headline'].astype(str).map(len)
real_len = real['headline'].astype(str).map(len)

# %%
fake_real_len = pd.DataFrame(fake_len, columns=['length'])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-43-9bf9b3ddc3c2> in <module>
# ----> 1 from pd.DataFrame import boxplot
#
# ImportError: No module named 'pd'

# %%
list(fake_len)
# Out:
# [68,
#  59,
#  65,
#  84,
#  36,
#  80,
#  83,
#  54,
#  50,
#  52,
#  43,
#  58,
#  65,
#  59,
#  97,
#  76,
#  61,
#  44,
#  52,
#  76,
#  89,
#  40,
#  65,
#  84,
#  46,
#  34,
#  74,
#  78,
#  80,
#  113,
#  41,
#  36,
#  95,
#  40,
#  43,
#  67,
#  69,
#  65,
#  57,
#  33,
#  84,
#  98,
#  88,
#  86,
#  40,
#  88,
#  58,
#  79,
#  27,
#  56,
#  57,
#  67,
#  76,
#  51,
#  98,
#  50,
#  41,
#  81,
#  73,
#  34,
#  98,
#  55,
#  80,
#  23,
#  50,
#  65,
#  74,
#  82,
#  40,
#  59,
#  68,
#  54,
#  64,
#  64,
#  82,
#  64,
#  32,
#  18,
#  82,
#  103,
#  34,
#  63,
#  50,
#  85,
#  68,
#  57,
#  81,
#  53,
#  73,
#  53,
#  29,
#  63,
#  61,
#  45,
#  63,
#  47,
#  35,
#  22,
#  109,
#  55,
#  70,
#  47,
#  36,
#  50,
#  70,
#  28,
#  33,
#  70,
#  133,
#  58,
#  79,
#  65,
#  64,
#  84,
#  98,
#  92,
#  86,
#  94,
#  86,
#  32,
#  118,
#  53,
#  68,
#  29,
#  86,
#  92,
#  101,
#  39,
#  59,
#  50,
#  21,
#  89,
#  67,
#  89,
#  26,
#  48,
#  56,
#  97,
#  86,
#  73,
#  41,
#  63,
#  83,
#  49,
#  39,
#  62,
#  96,
#  68,
#  68,
#  97,
#  48,
#  47,
#  69,
#  58,
#  103,
#  46,
#  63,
#  55,
#  31,
#  44,
#  75,
#  96,
#  91,
#  74,
#  80,
#  54,
#  34,
#  107,
#  93,
#  32,
#  77,
#  83,
#  102,
#  68,
#  30,
#  48,
#  76,
#  79,
#  52,
#  48,
#  72,
#  95,
#  74,
#  93,
#  32,
#  91,
#  86,
#  84,
#  18,
#  88,
#  44,
#  45,
#  96,
#  66,
#  93,
#  60,
#  43,
#  94,
#  87,
#  43,
#  71,
#  25,
#  43,
#  65,
#  116,
#  94,
#  57,
#  56,
#  56,
#  102,
#  106,
#  54,
#  103,
#  82,
#  71,
#  58,
#  43,
#  88,
#  77,
#  54,
#  77,
#  41,
#  63,
#  44,
#  82,
#  72,
#  33,
#  89,
#  29,
#  39,
#  46,
#  80,
#  59,
#  59,
#  64,
#  66,
#  107,
#  71,
#  59,
#  121,
#  57,
#  93,
#  56,
#  20,
#  73,
#  84,
#  63,
#  75,
#  80,
#  44,
#  83,
#  61,
#  54,
#  66,
#  60,
#  53,
#  60,
#  86,
#  90,
#  80,
#  40,
#  58,
#  42,
#  55,
#  53,
#  60,
#  57,
#  85,
#  106,
#  54,
#  67,
#  86,
#  66,
#  55,
#  61,
#  90,
#  84,
#  60,
#  83,
#  57,
#  80,
#  56,
#  69,
#  78,
#  97,
#  45,
#  81,
#  98,
#  46,
#  116,
#  76,
#  47,
#  37,
#  68,
#  56,
#  78,
#  104,
#  45,
#  22,
#  74,
#  37,
#  49,
#  63,
#  96,
#  84,
#  83,
#  70,
#  114,
#  55,
#  105,
#  41,
#  70,
#  86,
#  31,
#  47,
#  55,
#  82,
#  60,
#  51,
#  93,
#  50,
#  71,
#  59,
#  110,
#  100,
#  67,
#  59,
#  38,
#  57,
#  70,
#  59,
#  96,
#  52,
#  15,
#  50,
#  56,
#  63,
#  90,
#  46,
#  88,
#  22,
#  103,
#  72,
#  72,
#  47,
#  58,
#  78,
#  60,
#  92,
#  36,
#  70,
#  97,
#  79,
#  32,
#  100,
#  59,
#  76,
#  99,
#  31,
#  38,
#  75,
#  55,
#  59,
#  45,
#  26,
#  106,
#  25,
#  100,
#  42,
#  60,
#  20,
#  23,
#  25,
#  91,
#  36,
#  88,
#  71,
#  67,
#  55,
#  70,
#  96,
#  99,
#  123,
#  76,
#  74,
#  30,
#  78,
#  33,
#  71,
#  100,
#  70,
#  34,
#  62,
#  90,
#  50,
#  42,
#  29,
#  55,
#  90,
#  39,
#  75,
#  61,
#  57,
#  45,
#  35,
#  84,
#  37,
#  50,
#  60,
#  115,
#  91,
#  124,
#  40,
#  44,
#  94,
#  78,
#  81,
#  55,
#  84,
#  77,
#  67,
#  35,
#  71,
#  47,
#  70,
#  60,
#  58,
#  50,
#  60,
#  66,
#  52,
#  70,
#  89,
#  74,
#  61,
#  36,
#  46,
#  52,
#  91,
#  79,
#  49,
#  51,
#  38,
#  53,
#  45,
#  46,
#  61,
#  105,
#  75,
#  60,
#  84,
#  60,
#  69,
#  84,
#  86,
#  85,
#  94,
#  47,
#  67,
#  48,
#  67,
#  104,
#  54,
#  55,
#  44,
#  89,
#  53,
#  60,
#  74,
#  62,
#  53,
#  28,
#  51,
#  60,
#  55,
#  80,
#  46,
#  96,
#  58,
#  97,
#  100,
#  93,
#  89,
#  104,
#  27,
#  61,
#  52,
#  48,
#  74,
#  78,
#  64,
#  65,
#  49,
#  64,
#  56,
#  30,
#  59,
#  77,
#  16,
#  76,
#  48,
#  77,
#  108,
#  82,
#  65,
#  44,
#  59,
#  45,
#  65,
#  32,
#  71,
#  32,
#  38,
#  71,
#  65,
#  52,
#  55,
#  37,
#  83,
#  59,
#  101,
#  52,
#  104,
#  58,
#  68,
#  65,
#  52,
#  58,
#  36,
#  104,
#  57,
#  40,
#  25,
#  68,
#  87,
#  60,
#  63,
#  92,
#  91,
#  63,
#  55,
#  58,
#  77,
#  59,
#  58,
#  58,
#  63,
#  82,
#  80,
#  77,
#  55,
#  61,
#  31,
#  63,
#  36,
#  46,
#  63,
#  81,
#  104,
#  72,
#  37,
#  90,
#  41,
#  122,
#  46,
#  55,
#  45,
#  110,
#  75,
#  75,
#  75,
#  76,
#  68,
#  70,
#  59,
#  70,
#  91,
#  82,
#  100,
#  73,
#  79,
#  53,
#  99,
#  115,
#  94,
#  98,
#  52,
#  79,
#  46,
#  90,
#  52,
#  59,
#  76,
#  61,
#  64,
#  52,
#  47,
#  77,
#  66,
#  84,
#  113,
#  74,
#  13,
#  62,
#  82,
#  36,
#  42,
#  116,
#  81,
#  64,
#  68,
#  68,
#  62,
#  25,
#  82,
#  38,
#  53,
#  62,
#  62,
#  49,
#  52,
#  49,
#  42,
#  106,
#  49,
#  89,
#  52,
#  94,
#  51,
#  40,
#  44,
#  74,
#  78,
#  56,
#  69,
#  108,
#  54,
#  35,
#  53,
#  86,
#  38,
#  71,
#  106,
#  55,
#  100,
#  93,
#  61,
#  33,
#  62,
#  45,
#  28,
#  62,
#  83,
#  51,
#  88,
#  41,
#  94,
#  98,
#  33,
#  32,
#  57,
#  73,
#  78,
#  73,
#  127,
#  77,
#  238,
#  77,
#  68,
#  58,
#  69,
#  68,
#  132,
#  71,
#  51,
#  61,
#  111,
#  91,
#  79,
#  26,
#  78,
#  47,
#  99,
#  65,
#  60,
#  110,
#  99,
#  111,
#  62,
#  44,
#  65,
#  45,
#  47,
#  50,
#  63,
#  51,
#  35,
#  98,
#  72,
#  76,
#  78,
#  56,
#  121,
#  29,
#  52,
#  49,
#  49,
#  105,
#  107,
#  72,
#  79,
#  39,
#  52,
#  101,
#  53,
#  125,
#  56,
#  62,
#  54,
#  60,
#  66,
#  53,
#  52,
#  78,
#  80,
#  52,
#  56,
#  57,
#  63,
#  73,
#  41,
#  81,
#  75,
#  39,
#  23,
#  38,
#  64,
#  51,
#  86,
#  84,
#  51,
#  57,
#  50,
#  96,
#  26,
#  42,
#  73,
#  57,
#  55,
#  112,
#  65,
#  78,
#  43,
#  88,
#  30,
#  52,
#  32,
#  61,
#  58,
#  51,
#  62,
#  44,
#  32,
#  49,
#  95,
#  73,
#  78,
#  54,
#  98,
#  93,
#  34,
#  30,
#  66,
#  40,
#  55,
#  31,
#  75,
#  76,
#  73,
#  52,
#  26,
#  56,
#  36,
#  85,
#  84,
#  112,
#  80,
#  57,
#  46,
#  31,
#  93,
#  86,
#  75,
#  42,
#  71,
#  90,
#  43,
#  98,
#  34,
#  52,
#  72,
#  66,
#  70,
#  94,
#  59,
#  102,
#  75,
#  36,
#  87,
#  71,
#  68,
#  78,
#  80,
#  72,
#  95,
#  73,
#  69,
#  76,
#  134,
#  58,
#  108,
#  53,
#  65,
#  66,
#  73,
#  35,
#  73,
#  84,
#  78,
#  93,
#  48,
#  40,
#  77,
#  58,
#  80,
#  91,
#  72,
#  39,
#  76,
#  34,
#  46,
#  81,
#  43,
#  34,
#  77,
#  67,
#  62,
#  36,
#  49,
#  61,
#  51,
#  42,
#  60,
#  62,
#  64,
#  65,
#  69,
#  55,
#  45,
#  87,
#  54,
#  28,
#  70,
#  86,
#  67,
#  57,
#  21,
#  54,
#  81,
#  37,
#  61,
#  100,
#  67,
#  74,
#  85,
#  113,
#  48,
#  55,
#  70,
#  84,
#  101,
#  54,
#  75,
#  62,
#  71,
#  28,
#  53,
#  63,
#  80,
#  30,
#  36,
#  85,
#  58,
#  50,
#  49,
#  60,
#  62,
#  62,
#  68,
#  111,
#  59,
#  64,
#  54,
#  64,
#  57,
#  40,
#  76,
#  62,
#  63,
#  44,
#  49,
#  55,
#  81,
#  40,
#  54,
#  95,
#  41,
#  108,
#  90,
#  51,
#  49,
#  71,
#  47,
#  103,
#  84,
#  99,
#  68,
#  53,
#  54,
#  67,
#  40,
#  102,
#  69,
#  69,
#  40,
#  49,
#  110,
#  82,
#  71,
#  65,
#  69,
#  56,
#  59,
#  50,
#  96,
#  47,
#  43,
#  26,
#  88,
#  77,
#  75,
#  73,
#  133,
#  46,
#  38,
#  89,
#  77,
#  54,
#  113,
#  92,
#  81,
#  69,
#  59,
#  55,
#  109,
#  102,
#  69,
#  80,
#  56,
#  69,
#  61,
#  90,
#  34,
#  66,
#  39,
#  79,
#  40,
#  71,
#  51,
#  105,
#  85,
#  89,
#  71,
#  42,
#  34,
#  41,
#  80,
#  80,
#  53,
#  86,
#  67,
#  65,
#  60,
#  100,
#  54,
#  46,
#  40,
#  87,
#  48,
#  89,
#  ...]

# %%
boxplot = df.loc[df['is_sarcastic'] == 1].boxplot()
